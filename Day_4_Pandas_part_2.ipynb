# %%
import pandas as pd

# %%
movie=pd.read_csv("/content/movies.csv")

# %% [markdown]
# **Add new row in data frame**

# %%
dic = {
    "Name":['Rohit',"Verma","Pushpa","Ankit"],
    "Roll_No" : [2128,2128,2124,2104],
    "Education" :["M.sc","M.sc","M.sc","M.sc"]
}
d=pd.DataFrame(dic)

# %%
new_person=pd.Series(["Piyush",2129,"M.sc"],index=['Name',"Roll_No",'Education'])

# %%
d.append(new_person,ignore_index=True)
# Out:
#      Name  Roll_No Education
# 0   Rohit     2128      M.sc
# 1   Verma     2128      M.sc
# 2  Pushpa     2124      M.sc
# 3   Ankit     2104      M.sc
# 4  Piyush     2129      M.sc

# %%
new=pd.Series(["Vishal",2139,"M.sc"])

# %%
new
# Out:
# 0    Vishal
# 1      2139
# 2      M.sc
# dtype: object

# %%
d.append(new,ignore_index=True)
# Out:
#      Name  Roll_No Education       0       1     2
# 0   Rohit   2128.0      M.sc     NaN     NaN   NaN
# 1   Verma   2128.0      M.sc     NaN     NaN   NaN
# 2  Pushpa   2124.0      M.sc     NaN     NaN   NaN
# 3   Ankit   2104.0      M.sc     NaN     NaN   NaN
# 4     NaN      NaN       NaN  Vishal  2139.0  M.sc

# %%
new=pd.Series(["Money",2125,"M.sc"],index=["Name","Roll_No","Education"])

# %%
d.append(new,ignore_index=True)
# Out:
#      Name  Roll_No Education
# 0   Rohit     2128      M.sc
# 1   Verma     2128      M.sc
# 2  Pushpa     2124      M.sc
# 3   Ankit     2104      M.sc
# 4   Money     2125      M.sc

# %% [markdown]
# **Rename the columns**

# %%
d.rename(columns={"Name":"NAME"})
# Out:
#      NAME  Roll_No Education
# 0   Rohit     2128      M.sc
# 1   Verma     2128      M.sc
# 2  Pushpa     2124      M.sc
# 3   Ankit     2104      M.sc

# %%
d.rename(columns={"NAME":"Name","Education":"Education"})
# Out:
#      Name  Roll_No Education
# 0   Rohit     2128      M.sc
# 1   Verma     2128      M.sc
# 2  Pushpa     2124      M.sc
# 3   Ankit     2104      M.sc

# %% [markdown]
# **Select a multiple and Indivisual Data Or sclice of a DataFrame**

# %%
movie
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movie["title_x"]
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
movie[["title_x","imdb_rating"]]
# Out:
#                                    title_x  imdb_rating
# 0                 Uri: The Surgical Strike          8.4
# 1                            Battalion 609          4.1
# 2     The Accidental Prime Minister (film)          6.1
# 3                          Why Cheat India          6.0
# 4                          Evening Shadows          7.3
# ...                                    ...          ...
# 1624                 Tera Mera Saath Rahen          4.9
# 1625                  Yeh Zindagi Ka Safar          3.0
# 1626                       Sabse Bada Sukh          6.1
# 1627                                 Daaka          7.4
# 1628                              Humsafar          9.0
#
# [1629 rows x 2 columns]

# %%
movie[["title_x","imdb_rating"]].iloc[[1,3,4,5]]
# Out:
#            title_x  imdb_rating
# 1    Battalion 609          4.1
# 3  Why Cheat India          6.0
# 4  Evening Shadows          7.3
# 5      Soni (film)          7.2

# %%
movie.iloc[1:5]
# Out:
#                                 title_x    imdb_id  \
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
#                          title_y                 original_title  is_adult  \
# 1                  Battalion 609                  Battalion 609         0
# ...

# %%
movie.iloc[:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %% [markdown]
# **Set the index from the exiting data set**

# %%
new_movie=movie[["title_x","imdb_rating"]]

# %%
new_movie.set_index("title_x")
# Out:
#                                       imdb_rating
# title_x
# Uri: The Surgical Strike                      8.4
# Battalion 609                                 4.1
# The Accidental Prime Minister (film)          6.1
# Why Cheat India                               6.0
# Evening Shadows                               7.3
# ...                                           ...
# Tera Mera Saath Rahen                         4.9
# Yeh Zindagi Ka Safar                          3.0
# Sabse Bada Sukh                               6.1
# Daaka                                         7.4
# Humsafar                                      9.0
#
# [1629 rows x 1 columns]

# %% [markdown]
# **Selecting row based on the condition**

# %%
#import titanic dataset
titanic = pd.read_csv("/content/test[1].csv")
titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# **in this i  import the titanic dataset**

# %%
#in this dateset i want to select all the male on the titanic dataset
titanic[titanic["Sex"]=="male"]
# Out:
#      PassengerId  Pclass                          Name   Sex   Age  SibSp  \
# 0            892       3              Kelly, Mr. James  male  34.5      0
# 2            894       2     Myles, Mr. Thomas Francis  male  62.0      0
# 3            895       3              Wirz, Mr. Albert  male  27.0      0
# 5            897       3    Svensson, Mr. Johan Cervin  male  14.0      0
# 7            899       2  Caldwell, Mr. Albert Francis  male  26.0      1
# ..           ...     ...                           ...   ...   ...    ...
# 407         1299       1    Widener, Mr. George Dunton  male  50.0      1
# 413         1305       3            Spector, Mr. Woolf  male   NaN      0
# 415         1307       3  Saether, Mr. Simon Sivertsen  male  38.5      0
# 416         1308       3           Ware, Mr. Frederick  male   NaN      0
# 417         1309       3      Peter, Master. Michael J  male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# ...

# %%
#we select all the rows where the pasangers is a male 65 or older:
titanic[(titanic["Sex"]=="male") & (titanic["Age"] >65)]
# Out:
#     PassengerId  Pclass                Name   Sex   Age  SibSp  Parch  \
# 81          973       1  Straus, Mr. Isidor  male  67.0      1      0
#
#       Ticket      Fare    Cabin Embarked
# 81  PC 17483  221.7792  C55 C57        S

# %% [markdown]
# # **Replacing Values**

# %% [markdown]
# **we want to replace value in the dataframe using 'replace' method first we change the only specific columns values in dataframe**

# %%
titanic["Sex"]
# Out:
# 0        male
# 1      female
# 2        male
# 3        male
# 4      female
#         ...
# 413      male
# 414    female
# 415      male
# 416      male
# 417      male
# Name: Sex, Length: 418, dtype: object

# %%
titanic["Sex"].replace("female","women")
# Out:
# 0       male
# 1      women
# 2       male
# 3       male
# 4      women
#        ...
# 413     male
# 414    women
# 415     male
# 416     male
# 417     male
# Name: Sex, Length: 418, dtype: object

# %% [markdown]
# **We also change the multiple values in the dataframe columns**

# %%
titanic["Sex"]
# Out:
# 0        male
# 1      female
# 2        male
# 3        male
# 4      female
#         ...
# 413      male
# 414    female
# 415      male
# 416      male
# 417      male
# Name: Sex, Length: 418, dtype: object

# %%
titanic.replace(["female","male"],["Women","Men"])
# Out:
#      PassengerId  Pclass                                          Name    Sex  \
# 0            892       3                              Kelly, Mr. James    Men
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)  Women
# 2            894       2                     Myles, Mr. Thomas Francis    Men
# 3            895       3                              Wirz, Mr. Albert    Men
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  Women
# ..           ...     ...                                           ...    ...
# 413         1305       3                            Spector, Mr. Woolf    Men
# 414         1306       1                  Oliva y Ocana, Dona. Fermina  Women
# 415         1307       3                  Saether, Mr. Simon Sivertsen    Men
# 416         1308       3                           Ware, Mr. Frederick    Men
# 417         1309       3                      Peter, Master. Michael J    Men
#
# ...

# %% [markdown]
# **we can also change the values in the entire dataframe**

# %%
titanic.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
titanic.replace(1,"one")
# Out:
#      PassengerId Pclass                                          Name     Sex  \
# 0            892      3                              Kelly, Mr. James    male
# 1            893      3              Wilkes, Mrs. James (Ellen Needs)  female
# 2            894      2                     Myles, Mr. Thomas Francis    male
# 3            895      3                              Wirz, Mr. Albert    male
# 4            896      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..           ...    ...                                           ...     ...
# 413         1305      3                            Spector, Mr. Woolf    male
# 414         1306    one                  Oliva y Ocana, Dona. Fermina  female
# 415         1307      3                  Saether, Mr. Simon Sivertsen    male
# 416         1308      3                           Ware, Mr. Frederick    male
# 417         1309      3                      Peter, Master. Michael J    male
#
# ...

# %%
titanic.replace(0,"zero")
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age SibSp Parch              Ticket     Fare Cabin Embarked
# ...

# %%
titanic.replace([0,1],["zero","one"])
# Out:
#      PassengerId Pclass                                          Name     Sex  \
# 0            892      3                              Kelly, Mr. James    male
# 1            893      3              Wilkes, Mrs. James (Ellen Needs)  female
# 2            894      2                     Myles, Mr. Thomas Francis    male
# 3            895      3                              Wirz, Mr. Albert    male
# 4            896      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..           ...    ...                                           ...     ...
# 413         1305      3                            Spector, Mr. Woolf    male
# 414         1306    one                  Oliva y Ocana, Dona. Fermina  female
# 415         1307      3                  Saether, Mr. Simon Sivertsen    male
# 416         1308      3                           Ware, Mr. Frederick    male
# 417         1309      3                      Peter, Master. Michael J    male
#
# ...

# %% [markdown]
# ## **Rename columns**

# %%
titanic.rename(columns={"Pclass":"Passenger Class"})
# Out:
#      PassengerId  Passenger Class  \
# 0            892                3
# 1            893                3
# 2            894                2
# 3            895                3
# 4            896                3
# ..           ...              ...
# 413         1305                3
# 414         1306                1
# 415         1307                3
# 416         1308                3
# 417         1309                3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# ...

# %% [markdown]
# # **Multiple Columns Rename**

# %%
titanic.rename(columns={"Pclass":"Passenger Class","Sex":"Gender"})
# Out:
#      PassengerId  Passenger Class  \
# 0            892                3
# 1            893                3
# 2            894                2
# 3            895                3
# 4            896                3
# ..           ...              ...
# 413         1305                3
# 414         1306                1
# 415         1307                3
# 416         1308                3
# 417         1309                3
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# ...

# %%
titanic["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
titanic["Sex"].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %% [markdown]
# # **If we want to count the number of unique values**

# %%
titanic["Sex"]
# Out:
# 0        male
# 1      female
# 2        male
# 3        male
# 4      female
#         ...
# 413      male
# 414    female
# 415      male
# 416      male
# 417      male
# Name: Sex, Length: 418, dtype: object

# %%
titanic["Sex"].nunique()
# Out:
# 2

# %%
titanic["Pclass"].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64

# %%
titanic["Pclass"].nunique()
# Out:
# 3

# %%
titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# ## **Deleting Columns**

# %%
titanic.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
titanic.drop("Pclass",axis=1)
# Out:
#      PassengerId                                          Name     Sex   Age  \
# 0            892                              Kelly, Mr. James    male  34.5
# 1            893              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2            894                     Myles, Mr. Thomas Francis    male  62.0
# 3            895                              Wirz, Mr. Albert    male  27.0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..           ...                                           ...     ...   ...
# 413         1305                            Spector, Mr. Woolf    male   NaN
# 414         1306                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415         1307                  Saether, Mr. Simon Sivertsen    male  38.5
# 416         1308                           Ware, Mr. Frederick    male   NaN
# 417         1309                      Peter, Master. Michael J    male   NaN
#
# ...

# %% [markdown]
# **We can drop the nultiple columns**

# %%
titanic.drop(["Age","Sex"],axis=1)
# Out:
#      PassengerId  Pclass                                          Name  SibSp  \
# 0            892       3                              Kelly, Mr. James      0
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)      1
# 2            894       2                     Myles, Mr. Thomas Francis      0
# 3            895       3                              Wirz, Mr. Albert      0
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)      1
# ..           ...     ...                                           ...    ...
# 413         1305       3                            Spector, Mr. Woolf      0
# 414         1306       1                  Oliva y Ocana, Dona. Fermina      0
# 415         1307       3                  Saether, Mr. Simon Sivertsen      0
# 416         1308       3                           Ware, Mr. Frederick      0
# 417         1309       3                      Peter, Master. Michael J      1
#
# ...

# %% [markdown]
# **We can also drop the columns by indexing**

# %%
titanic.drop(titanic.columns[1],axis=1)
# Out:
#      PassengerId                                          Name     Sex   Age  \
# 0            892                              Kelly, Mr. James    male  34.5
# 1            893              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2            894                     Myles, Mr. Thomas Francis    male  62.0
# 3            895                              Wirz, Mr. Albert    male  27.0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..           ...                                           ...     ...   ...
# 413         1305                            Spector, Mr. Woolf    male   NaN
# 414         1306                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415         1307                  Saether, Mr. Simon Sivertsen    male  38.5
# 416         1308                           Ware, Mr. Frederick    male   NaN
# 417         1309                      Peter, Master. Michael J    male   NaN
#
# ...

# %%
titanic.drop(titanic.columns[0:2],axis=1)
# Out:
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
# ...

# %%
titanic.drop(titanic.columns[2:5],axis=1)
# Out:
#      PassengerId  Pclass  SibSp  Parch              Ticket      Fare Cabin  \
# 0            892       3      0      0              330911    7.8292   NaN
# 1            893       3      1      0              363272    7.0000   NaN
# 2            894       2      0      0              240276    9.6875   NaN
# 3            895       3      0      0              315154    8.6625   NaN
# 4            896       3      1      1             3101298   12.2875   NaN
# ..           ...     ...    ...    ...                 ...       ...   ...
# 413         1305       3      0      0           A.5. 3236    8.0500   NaN
# 414         1306       1      0      0            PC 17758  108.9000  C105
# 415         1307       3      0      0  SOTON/O.Q. 3101262    7.2500   NaN
# 416         1308       3      0      0              359309    8.0500   NaN
# 417         1309       3      1      1                2668   22.3583   NaN
#
#     Embarked
# 0          Q
# 1          S
# 2          Q
# ...

# %% [markdown]
# # **Deleting a Row**

# %%
titanic.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
titanic.drop(0,axis=0)
# Out:
#      PassengerId  Pclass                                          Name  \
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                    Svensson, Mr. Johan Cervin
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
titanic.drop([2,3,5,7,9],axis=0)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6            898       3                          Connolly, Miss. Kate
# 8            900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
titanic[titanic["Age"] != "male"]
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# # **You want to  drop duplicated rows from you'r DataFrame**

# %%
titanic.drop_duplicates()
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
titanic.nunique()
# Out:
# PassengerId    418
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %% [markdown]
# **Drop duplicates values in the perticular columns**

# %%
titanic.drop_duplicates(subset=["Sex"])
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S

# %%
titanic.drop_duplicates(subset="Pclass")
# Out:
#     PassengerId  Pclass                        Name   Sex   Age  SibSp  Parch  \
# 0           892       3            Kelly, Mr. James  male  34.5      0      0
# 2           894       2   Myles, Mr. Thomas Francis  male  62.0      0      0
# 11          903       1  Jones, Mr. Charles Cresson  male  46.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 2   240276   9.6875   NaN        Q
# 11     694  26.0000   NaN        S
